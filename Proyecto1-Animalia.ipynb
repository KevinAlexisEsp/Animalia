# %%
import numpy as np
import pandas as pd

import requests
from  bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from tqdm.notebook import tqdm
from pprint import pprint

import json

from time import sleep
API_KEY = "patrGrprzpqjMJ6ck.2039bfe0dca5e50e2ee97c4dbd381d054983006a8e31b062629cdbdcccdf8e93"
BASE_ID = "appnoz8hECBYemFZr"
TABLE_NAME = "tblzGPftGkpBXpaWb"

# %%
chrome_driver = "chromedriver.exe"

url_animalia = "https://animalia.bio/mammals"

browser = webdriver.Chrome(executable_path = chrome_driver)

browser.get(url = url_animalia)

browser.maximize_window()
sleep(3)
# Aceptar Cookies
browser.find_element(by = By.CSS_SELECTOR, value = 'body > div.stpd_cmp > div > div > div:nth-child(3) > div > button').click()
sleep(1)
# EL BOTON DESAPARECE PONER UN WHILE MIENTRAS EL BOTON EXISTA.
a = browser.find_element(by = By.CSS_SELECTOR, value = "body > div.f-page.container > div.f-page__content > div > div.animals-list-with-ads > div.animals.table > div.paginator > div.load-more-container > span")
try:
    while a:
        elemento = browser.find_element(by = By.CSS_SELECTOR, value = "body > div.f-page.container > div.f-page__content > div > div.animals-list-with-ads > div.animals.table > div.paginator > div.load-more-container > span")
        sleep(2)
        elemento = browser.execute_script("arguments[0].scrollIntoView({block: 'center'});", elemento)
        sleep(2)
        browser.find_element(by = By.CSS_SELECTOR, value = "body > div.f-page.container > div.f-page__content > div > div.animals-list-with-ads > div.animals.table > div.paginator > div.load-more-container > span").click()
        sleep(2)
except:
    sleep(2)

enlaces = browser.find_elements(by = By.CLASS_NAME, value = "animals-invert__item")
                                                            
lista_url = []
# Itera a través de los enlaces y obtén sus atributos 'href'
for enlace in tqdm(enlaces):
    href = enlace.get_attribute('href')
    if href:
        # print(href)
        lista_url.append(href)
# Out:
#   0%|          | 0/6350 [00:00<?, ?it/s]

# %%
lista_url2 = lista_url

# %%
# Creamos el archivo de texto con las urls utilizadas:

with open("Lista_urls.txt", "w") as archivo:
    for elemento in lista_url:
        archivo.write(elemento + "\n")

# %%
with open('Lista_urls.txt', 'r') as archivo:
    # Lee todas las líneas del archivo y elimina los espacios en blanco y caracteres de nueva línea
    lista_url = [line.strip() for line in archivo.readlines()]

# %%
# %time
nombre_animal = []
datos_animales_reset = []
datos_animales = []
kingdom = []
phylum = []
subphylum = []
claass = []
order = []
suborder = []
infraorder = []
family = []
genus = []
popu_size = []
life_span = []
top_speed = []
weight_list = []
lenght_list = []
height_list = []

dieta = [] # Carnivoro, hervivo, omnivoro     .
horario = [] # nocturno, diurno
reproduccion = [] # oviparo, viviparo
estilo_de_vida = [] #nomada, no migrande, migrande
sociabilidad = [] #social, solitario
domestiscado = [] #domesticado, siempre y cuando exista, salvaje
tipo = [] #acuatico, terresrte
caracteristicas = []
horario_chiquito = []
veneno = []
# Aquí empieza lo de Cristian
lista_biome = []
lista_biome_reseteada = []
lista_clime = []
lista_clime_reseteada = []
lista = []
lista2 = []
lista_global = []
lista_global2 = []
lista_tipo_relación = []
lista_epoca_reproducción = []
lista_numero_crias = []
lista_numero_crias_final = []
lista_independientes = []
lista_periodo_embarazo = []
lista_final = []
lista_numero_crias_media = []
lista_periodo = []
lista_independientes_final = []
lista_forest = []
lista_dunes = []
lista_rivers = []
lista_marine = []
lista_reef = []
lista_semi_desert = []
lista_steppe = []
lista_freshwater = []
lista_abyssal_zone = []
lista_icecap = []
lista_rainforest = []
lista_intertidal_zone = []
lista_urban = []
lista_benthic = []
lista_rocky_areas = []
lista_wetlands = []
lista_marsh = []
lista_lakes = []
lista_coastal = []
lista_chaparral = []
lista_shrubland = []
lista_antrophogenic = []
lista_estuaries = []
lista_oceanic_pelagic_zone = []
lista_caves = []
lista_grassland = []
lista_savanna = []
lista_mountains = []
lista_riparian = []
lista_neritic_zone = []
lista_agricultural = []
lista_polar = []
lista_cold = []
lista_temperate = []
lista_tropical = []
lista_arid = []
#Listas de Lorena
lista_continentes = []
lista_tendencia_pob = []
lista_estado_pob = []
lista_Europa = []
lista_Asia = []
lista_Oceania = []
lista_Africa = []
lista_Antarctica = []
lista_SouthAmerica = []
lista_NorthAmerica = []

for url in tqdm(lista_url[0:]):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    try:
        animal = soup.find("h1", class_ = "a-h1").text.replace("\n","")
        nombre_animal.append(animal)
        print(animal)
    except:
        nombre_animal.append(np.nan)
    #     DATOOS ANIAMLES(KINGDOM, PHYLUM, SUBPHYYLUM, CLASS, ORDER, SUBORDER, FAMILY, GENUS)
    try:
#         ENTRAMOS EN LA CLASE DONDE ESTAN LOS DATOS DE LOS ANIMALES.
        datos = soup.find_all("a", class_ = "s-char-kinds__name")
#       SE CORRIGE UNA ENTRADA DE UNOS POCOS CASOS QUE TIENEN TEXTO EXTRA.
        if datos[0].text.replace("\n","") != "Animalia":
            datos.remove(datos[0])
#        SE CREA UNA LISTA QUE SE RESETEAN PARA PODER SEPARAR LOS DATOS E ITERERAR COMO ELEMENTOS DE LISTA Y NO COMO CARACTER.
        for n in datos:
            datos_animales_reset.append(n.text)
        datos_animales.append(datos_animales_reset)
        datos_animales_reset = []
#         KINGDOM
        try:
            kingdom.append(datos_animales[0][0])
        except:
            kingdom.append(np.nan)
#          PHYLUM
        try:
            phylum.append(datos_animales[0][1])
        except:
            phylum.append(np.nan)
#       SUBPHYLUM
            
        try:
            subphylum.append(datos_animales[0][2])
        except:
            subphylum.append(np.nan) 
#      CLASS, (ESCRITO COMO CLAASS PARA NO SOBREESCRIBIR UNA VARIABLE DE PYTHON)

        try:
            claass.append(datos_animales[0][3])
        except:
            claass.append(np.nan) 
#        ORDER
        try:
            order.append(datos_animales[0][4])
        except:
            order.append(np.nan) 
#         SUBORDER
        try:
            soup.find_all("div", class_ = "s-char-kinds__attr")[5].text.replace("\n","") == "Suborder"
            suborder.append(datos_animales[0][5])
#        FAMILY
            try:
                family.append(datos_animales[0][6])
            except:
                family.append(np.nan)
#        GENUS
            try:
                genus.append(datos_animales[0][7])
            except:
                genus.append(np.nan)
        except:
            suborder.append(np.nan)
#        FAMILY
            try:
                family.append(datos_animales[0][5])
            except:
                family.append(np.nan)
#        GENUS
            try:
                genus.append(datos_animales[0][6])
            except:
                genus.append(np.nan)
#      SE RESETEA LA LISTA PARA EL SIGUIENTE LINK.
        datos_animales = []
#     POPULATION SIZE, LIFE SPAN, TOP SPEED, WEIGHT, LENGTH.
    except:
        kingdom.append(np.nan)
        phylum.append(np.nan)
        subphylum.append(np.nan) 
        claass.append(np.nan)
        order.append(np.nan) 
        suborder.append(np.nan)
        family.append(np.nan)
        genus.append(np.nan)

#       POBLACION
    try:
        soup.find_all("div", class_ = "s-char-char__name")[0].text.replace("\n","") == "Population size"
        try:
            popu = soup.find_all("div", class_ = "s-char-char__num")[0].text.replace("\n","")
            popu = popu.replace(",",".")
            a = (float(popu.split("-")[0]))
            b = (float(popu.split("-")[1].split(" ")[0])) 
            c = ((b - a)/2)+a
            if len(str(c)) <= 5 & len(str(c)) > 3:
                popu_size.append(c*1000)
            elif len(str(c)) <=3:
                popu_size.append(c)
            elif soup.find_all("div", class_ = "s-char-char__num")[0].text.replace("\n","") == "aBnove":
                c = soup.find_all("div", class_ = "s-char-char__num")[2].text.replace("\n","") * 1000000
                popu_size.append(c)

            elif soup.find_all("div", class_ = "s-char-char__num")[0].text.replace("\n","") == "Bnelow":
                c = soup.find_all("div", class_ = "s-char-char__num")[2].text.replace("\n","")
                c = c.replace(",",".")
                popu_size.append(c)


            else:
                popu_size.append(c)
        except:
            c = soup.find_all("div", class_ = "s-char-char__num")[0].text.replace("\n","")
            if c == "Unknown":
                popu_size.append(np.nan)

            elif len(str(c)) <=3:
                c = popu.replace(",",".")
                popu_size.append(c)

            else:
                c = popu.replace(",",".")
                c = float(c) * 1000
                popu_size.append(c)


    except:
        popu_size.append(np.nan)

           # LIFE SPAN
    animal
    x = len(life_span)
    for n in range(len(soup.find_all("div", class_ = "s-char-char__name"))):
         if soup.find_all("div", class_ = "s-char-char__name")[n].text.replace("\n","") == "Life Span":
            life =soup.find_all("div", class_:="s-char-char__num")
            life = life[n].text.replace("\n","")
            try:
                life = life.replace(",",".")
                a = (float(life.split("-")[0]))
                b = (float(life.split("-")[1].split(" ")[0])) 
                c = ((b - a)/2)+a
                life_span.append(c)
            except:
                try:
                    c = life
                    c = float(c.split(" ")[0]) 
                    life_span.append((c))
                except:
                    try:
                        c = float(c.split(" ")[1]) 
                        life_span.append((c))
                    except:
                        try:
                            c = float(c.split(" ")[2]) 
                            life_span.append((c))
                        except:
                            try:
                                c = (float(life.split("-")[0]))
                                life_span.append((c))
                            except:
                                try:
                                    c = float(life.split("O")[1].split(" ")[0])
                                    life_span.append((c)) 
                                except:
                                    life_span.append(np.nan)
                        
    if x == len(life_span):
        life_span.append(np.nan)
      # TOP SPEED 
    
    try:
        speed =soup.find("div", class_:="characteristic-value speed_1").text
        if len(speed.split("-")) ==2:
            a = (float(speed.split("-")[0]))
            b = (float(speed.split("-")[1])) 
            speed = ((b - a)/2)+a
            top_speed.append(speed)
        else:
            top_speed.append(speed)       
    except:
        top_speed.append(np.nan) 

#     WEIGHT
    try:
        weight =soup.find("div", class_:="characteristic-value weight_1").text
        if len(weight.split("-")) ==2:
            a = (float(weight.split("-")[0]))
            b = (float(weight.split("-")[1])) 
            weight = ((b - a)/2)+a
            if soup.find("span", attrs={'action': 'weight_1'}).text == "t":
                 weight_list.append(weight*1000)
            elif soup.find("span", attrs={'action': 'weight_1'}).text == "g":
                 weight_list.append(weight/1000)
            else:
                weight_list.append(weight)
        else:
            weight_list.append(weight)
    except:
        weight_list.append(np.nan)
#  lENGHT
    try:
        lenght =soup.find("div", class_:="characteristic-value lengths_1").text
        if len(lenght.split("-")) ==2:
            a = (float(lenght.split("-")[0]))
            b = (float(lenght.split("-")[1])) 
            lenght = ((b - a)/2)+a
            lenght_list.append(lenght)
        else:
            lenght_list.append(lenght)
        
    except:
        lenght_list.append(np.nan)
# HEIGHT
    try:
        height =soup.find("div", class_:="characteristic-value height_1").text
        if len(height.split("-")) ==2:
            a = (float(height.split("-")[0]))
            b = (float(height.split("-")[1])) 
            height = ((b - a)/2)+a
            height_list.append(height)
      
        else:
            height_list.append(height)

        
    except:
        height_list.append(np.nan)
   
   #SEGUNDA PARTE
    
    len_dieta = len(dieta)
    len_horario_chiquito = len(horario_chiquito)
    len_reproduccion = len(reproduccion) 
    len_estilo_de_vida = len(estilo_de_vida)
    len_sociabilidad = len(sociabilidad)
    len_domestiscado = len(domestiscado)
    len_tipo = len(tipo)
    len_veneno = len(veneno)
    agregado_nocturnal = False
    agregado_tipo = False
    agregado_sociabilidad = False
    agregado_estilo_de_vida = False
    elementos_a = soup.find_all("a", class_ = "s-char-status-item")
    for elemento_a in elementos_a:
        titulo = elemento_a.get('title')
      #DIETA
        try:
            if titulo == "Omnivore":
                dieta.append(titulo)
        except:
            if titulo =="Carnivore":
                dieta.append(titulo)
            elif titulo =="Herbivore":
                dieta.append(titulo)
      #HORARIO
        
        if titulo == "Crepuscular" or titulo == "Nocturnal":
            if not agregado_nocturnal:
                horario_chiquito.append("Nocturnal")
                agregado_nocturnal = True
        
        elif titulo == "Diurnal":
            horario_chiquito.append(titulo)
    # reproduccion
        elif titulo == "Oviparous":
            reproduccion.append(titulo)
        elif titulo == "Viviparous":
            reproduccion.append(titulo)
    #estilo_de_vida
        elif titulo == "Migrating" or titulo == "Not a migrant":
            if not agregado_estilo_de_vida:
                estilo_de_vida.append(titulo)
                agregado_estilo_de_vida = True
            
    # socialbilidad
        elif titulo == "Social" or titulo == "Solitary":
            if not agregado_sociabilidad:
                sociabilidad.append(titulo)
                agregado_sociabilidad = True 
        
    # DOMESTICADO
        elif titulo == "Domesticated":
                domestiscado.append(titulo)
     # tipo    
        elif titulo == "Aquatic" or  titulo == "Terrestrial":
            if not agregado_tipo:
                tipo.append(titulo)
                agregado_tipo = True
    # Veneno
        elif titulo == "Venomous":
            veneno.append(titulo)
            
            
           
    if len_dieta == len(dieta):
        dieta.append(np.nan)
    if len_horario_chiquito == len(horario_chiquito):
        horario_chiquito.append(np.nan)
    if len_reproduccion == len(reproduccion):
        reproduccion.append(np.nan)
    if len_estilo_de_vida == len(estilo_de_vida):
        estilo_de_vida.append(np.nan)
    if len_sociabilidad == len(sociabilidad):
        sociabilidad.append(np.nan)
    if len_domestiscado== len(domestiscado):
        domestiscado.append("No domesticated")
    if len_tipo == len(tipo):
        tipo.append(np.nan)
    if len_veneno == len(veneno):
        veneno.append("No")
    horario.append(horario_chiquito)
    horario_chiquito = []
    
#Esto es de Cristian   
    try:
        for zone in soup.find_all("a", class_= "s-distr-zone-item"):
            lista_biome.append(zone.text.replace("\n",""))
        lista_biome_reseteada.append(lista_biome)
        lista_biome = []
    except:
        lista_biome.append(np.nan)
        lista_biome_reseteada.append(lista_biome)
    try:
        for clime in soup.find_all("a", class_= "s-distr-climate__link"):
            lista_clime.append(clime.text.replace("\n",""))
        lista_clime_reseteada.append(lista_clime)
        lista_clime = []
    except:
        lista_clime.append(np.nan)
        lista_clime_reseteada.append(lista_clime)
    try:
        reproduction = soup.find_all("div", class_= "s-mating-char")
        colum = soup.find_all("div", class_="s-mating-slug")
        for n in reproduction:
            try:
                lista.append(n.text)
            except:
                lista.append(np.nan)
        lista_global.append(lista)
        lista = []
        for m in colum:
            try:
                lista2.append(m.text.replace("\n",""))
            except:
                lista2.append(np.nan)
        lista_global2.append(lista2)
        lista2 = []
    except:
        lista_global.append(np.nan)
        lista_global2.append(np.nan)
#Esto es de Lorena
    
    try:
        geography = soup.find("div", class_ = "col-sm-9").text.replace("\n","").replace("South America", "SouthAmerica").replace("North America", "NorthAmerica")
        lista_continentes.append(geography)
    except:
        lista_continentes.append(np.nan)
    try:
        population = soup.find_all("div", class_ = "col-sm-7")
        lista_tendencia_pob.append(population[0].text.replace("\n",""))
    except:
        lista_tendencia_pob.append(np.nan)
    try:
        status = soup.find_all("div", class_ = "col-sm-7 col-md-8")
        lista_estado_pob.append(status[1].text.replace("\n",""))
    except:
        lista_estado_pob.append(np.nan)
        
    
    
        
#Aquí empiezan los biomas y climas Cristian

for n in lista_biome_reseteada:
    if "Forest" in n or "Montane forest" in n or "Cloud forest" in n or "Woodland" in n:
        lista_forest.append("Yes")
    elif n == []:
        lista_forest.append(np.nan)
    else:
        lista_forest.append("No")
        
for n in lista_biome_reseteada:
    if "Grassland" in n or "Prairie" in n:
        lista_grassland.append("Yes")
    elif n == []:
        lista_grassland.append(np.nan)
    else:
        lista_grassland.append("No")

for n in lista_biome_reseteada:
    if "Reef" in n or "Coral reef" in n:
        lista_reef.append("Yes")
    elif n == []:
        lista_reef.append(np.nan)
    else:
        lista_reef.append("No")

for n in lista_biome_reseteada:
    if "Suburban" in n or "Urban wildlife" in n:
        lista_urban.append("Yes")
    elif n == []:
        lista_urban.append(np.nan)
    else:
        lista_urban.append("No")

for n in lista_biome_reseteada:
    if "Bog" in n or "Marsh" in n or "Swamp" in n:
        lista_marsh.append("Yes")
    elif n == []:
        lista_marsh.append(np.nan)
    else:
        lista_marsh.append("No")
        
for n in lista_biome_reseteada:
    if "Freshwater" in n or "Brackish water" in n:
        lista_freshwater.append("Yes")
    elif n == []:
        lista_freshwater.append(np.nan)
    else:
        lista_freshwater.append("No")

for n in lista_biome_reseteada:
    if "Riparian" in n:
        lista_riparian.append("Yes")
    elif n == []:
        lista_riparian.append(np.nan)
    else:
        lista_riparian.append("No")
        
for n in lista_biome_reseteada:
    if "Rainforest" in n or "Tropical rainforest" in n:
        lista_rainforest.append("Yes")
    elif n == []:
        lista_rainforest.append(np.nan)
    else:
        lista_rainforest.append("No")
        
for n in lista_biome_reseteada:
    if "Savanna" in n:
        lista_savanna.append("Yes")
    elif n == []:
        lista_savanna.append(np.nan)
    else:
        lista_savanna.append("No")
        
for n in lista_biome_reseteada:
    if "Chaparral" in n:
        lista_chaparral.append("Yes")
    elif n == []:
        lista_chaparral.append(np.nan)
    else:
        lista_chaparral.append("No")
        
for n in lista_biome_reseteada:
    if "Shrubland" in n:
        lista_shrubland.append("Yes")
    elif n == []:
        lista_shrubland.append(np.nan)
    else:
        lista_shrubland.append("No")
        
for n in lista_biome_reseteada:
    if "Lakes" in n:
        lista_lakes.append("Yes")
    elif n == []:
        lista_lakes.append(np.nan)
    else:
        lista_lakes.append("No")
        
for n in lista_biome_reseteada:
    if "Semi-desert" in n:
        lista_semi_desert.append("Yes")
    elif n == []:
        lista_semi_desert.append(np.nan)
    else:
        lista_semi_desert.append("No")
        
for n in lista_biome_reseteada:
    if "Benthic" in n:
        lista_benthic.append("Yes")
    elif n == []:
        lista_benthic.append(np.nan)
    else:
        lista_benthic.append("No")

for n in lista_biome_reseteada:
    if "Intertidal zone" in n:
        lista_intertidal_zone.append("Yes")
    elif n == []:
        lista_intertidal_zone.append(np.nan)
    else:
        lista_intertidal_zone.append("No")

for n in lista_biome_reseteada:
    if "Wetlands " in n:
        lista_wetlands.append("Yes")
    elif n == []:
        lista_wetlands.append(np.nan)
    else:
        lista_wetlands.append("No")

for n in lista_biome_reseteada:
    if "Abyssal zone" in n:
        lista_abyssal_zone.append("Yes")
    elif n == []:
        lista_abyssal_zone.append(np.nan)
    else:
        lista_abyssal_zone.append("No")
        
for n in lista_biome_reseteada:
    if "Rivers" in n:
        lista_rivers.append("Yes")
    elif n == []:
        lista_rivers.append(np.nan)
    else:
        lista_rivers.append("No")
        
for n in lista_biome_reseteada:
    if "Oceanic pelagic zone" in n:
        lista_oceanic_pelagic_zone.append("Yes")
    elif n == []:
        lista_oceanic_pelagic_zone.append(np.nan)
    else:
        lista_oceanic_pelagic_zone.append("No")
        
for n in lista_biome_reseteada:
    if "Dunes" in n:
        lista_dunes.append("Yes")
    elif n == []:
        lista_dunes.append(np.nan)
    else:
        lista_dunes.append("No")
        
for n in lista_biome_reseteada:
    if "Caves" in n:
        lista_caves.append("Yes")
    elif n == []:
        lista_caves.append(np.nan)
    else:
        lista_caves.append("No")
        
for n in lista_biome_reseteada:
    if "Steppe" in n:
        lista_steppe.append("Yes")
    elif n == []:
        lista_steppe.append(np.nan)
    else:
        lista_steppe.append("No")
    
for n in lista_biome_reseteada:
    if "Marine" in n:
        lista_marine.append("Yes")
    elif n == []:
        lista_marine.append(np.nan)
    else:
        lista_marine.append("No")

for n in lista_biome_reseteada:
    if "Icecap" in n:
        lista_icecap.append("Yes")
    elif n == []:
        lista_icecap.append(np.nan)
    else:
        lista_icecap.append("No")
        
for n in lista_biome_reseteada:
    if "Mountains" in n:
        lista_mountains.append("Yes")
    elif n == []:
        lista_mountains.append(np.nan)
    else:
        lista_mountains.append("No")
        
for n in lista_biome_reseteada:
    if "Agricultural" in n:
        lista_agricultural.append("Yes")
    elif n == []:
        lista_agricultural.append(np.nan)
    else:
        lista_agricultural.append("No")
        
for n in lista_biome_reseteada:
    if "Anthropogenic biome" in n:
        lista_antrophogenic.append("Yes")
    elif n == []:
        lista_antrophogenic.append(np.nan)
    else:
        lista_antrophogenic.append("No")
        
for n in lista_biome_reseteada:
    if "Neritic zone" in n:
        lista_neritic_zone.append("Yes")
    elif n == []:
        lista_neritic_zone.append(np.nan)
    else:
        lista_neritic_zone.append("No")
        
for n in lista_biome_reseteada:
    if "Rocky areas " in n:
        lista_rocky_areas.append("Yes")
    elif n == []:
        lista_rocky_areas.append(np.nan)
    else:
        lista_rocky_areas.append("No")
        
for n in lista_biome_reseteada:
    if "Estuaries" in n:
        lista_estuaries.append("Yes")
    elif n == []:
        lista_estuaries.append(np.nan)
    else:
        lista_estuaries.append("No")
        
for n in lista_biome_reseteada:
    if "Coastal" in n:
        lista_coastal.append("Yes")
    elif n == []:
        lista_coastal.append(np.nan)
    else:
        lista_coastal.append("No")

for n in lista_clime_reseteada:
    if "Polar" in n:
        lista_polar.append("Yes")
    elif n == []:
        lista_polar.append(np.nan)
    else:
        lista_polar.append("No")

for n in lista_clime_reseteada:
    if "Arid" in n:
        lista_arid.append("Yes")
    elif n == []:
        lista_arid.append(np.nan)
    else:
        lista_arid.append("No")

for n in lista_clime_reseteada:
    if "Temperate" in n:
        lista_temperate.append("Yes")
    elif n == []:
        lista_temperate.append(np.nan)
    else:
        lista_temperate.append("No")
        
for n in lista_clime_reseteada:
    if "Cold" in n:
        lista_cold.append("Yes")
    elif n == []:
        lista_cold.append(np.nan)
    else:
        lista_cold.append("No")

for n in lista_clime_reseteada:
    if "Tropical" in n:
        lista_tropical.append("Yes")
    elif n == []:
        lista_tropical.append(np.nan)
    else:
        lista_tropical.append("No")
        
#Esto son los continentes de Lorena

for continente in lista_continentes:
    if isinstance(continente, str):
        if "Asia" in continente or "Asia," in continente: 
            lista_Asia.append("Yes")
        elif "Europe" in continente or "Europe," in continente or "Antarctica" in continente or "Antarctica," in continente or "Africa" in continente or "Africa," in continente or "SouthAmerica" in continente or "SouthAmerica," in continente or "NorthAmerica" in continente or "NorthAmerica," in continente or "Oceania" in continente or "Oceania," in continente:
            lista_Asia.append("No")
        else:
            lista_Asia.append(np.nan)
    else:
        lista_Asia.append(np.nan)
        
for continente in lista_continentes:
    if isinstance(continente, str):
        if "Europe" in continente or "Europe," in continente: 
            lista_Europa.append("Yes")
        elif "Oceania" in continente or "Oceania," in continente or "Antarctica" in continente or "Antarctica," in continente or "Africa" in continente or "Africa," in continente or "SouthAmerica" in continente or "SouthAmerica," in continente or "NorthAmerica" in continente or "NorthAmerica," in continente or "Asia" in continente or "Asia," in continente:
            lista_Europa.append("No")
        else: 
            lista_Europa.append(np.nan)
    else:
        lista_Europa.append(np.nan)
        
for continente in lista_continentes:
    if isinstance(continente, str):
        if "Oceania" in continente or "Oceania," in continente: 
            lista_Oceania.append("Yes")
        elif "Europe" in continente or "Europe," in continente or "Antarctica" in continente or "Antarctica," in continente or "Africa" in continente or "Africa," in continente or "SouthAmerica" in continente or "SouthAmerica," in continente or "NorthAmerica" in continente or "NorthAmerica," in continente or "Asia" in continente or "Asia," in continente:
            lista_Oceania.append("No")
        else:
            lista_Oceania.append(np.nan)
    else:
        lista_Oceania.append(np.nan)
        
for continente in lista_continentes:
    if isinstance(continente, str):
        if "Antarctica" in continente or "Antarctica," in continente: 
            lista_Antarctica.append("Yes")
        elif "Europe" in continente or "Europe," in continente or "Oceania" in continente or "Oceania," in continente or "Africa" in continente or "Africa," in continente or "SouthAmerica" in continente or "SouthAmerica," in continente or "NorthAmerica" in continente or "NorthAmerica," in continente or "Asia" in continente or "Asia," in continente:
            lista_Antarctica.append("No")
        else:
            lista_Antarctica.append(np.nan)
    else:
        lista_Antarctica.append(np.nan)
            
for continente in lista_continentes:
    if isinstance(continente, str):
        if "Africa" in continente or "Africa," in continente: 
            lista_Africa.append("Yes")
        elif "Europe" in continente or "Europe," in continente or "Antarctica" in continente or "Antarctica," in continente or "Oceania" in continente or "Oceania," in continente or "SouthAmerica" in continente or "SouthAmerica," in continente or "NorthAmerica" in continente or "NorthAmerica," in continente or "Asia" in continente or "Asia," in continente:
            lista_Africa.append("No")
        else:
            lista_Africa.append(np.nan)
    else: 
        lista_Africa.append(np.nan)
        
for continente in lista_continentes:
    if isinstance(continente, str):
        if "SouthAmerica" in continente or "SouthAmerica," in continente: 
            lista_SouthAmerica.append("Yes")
        elif "Europe" in continente or "Europe," in continente or "Antarctica" in continente or "Antarctica," in continente or "Africa" in continente or "Africa," in continente or "Oceania" in continente or "Oceania," in continente or "NorthAmerica" in continente or "NorthAmerica," in continente or "Asia" in continente or "Asia," in continente:
            lista_SouthAmerica.append("No")
        else:
            lista_SouthAmerica.append(np.nan)
    else:
        lista_SouthAmerica.append(np.nan)
        
for continente in lista_continentes:
    if isinstance(continente, str):
        if "NorthAmerica" in continente or "NorthAmerica," in continente: 
            lista_NorthAmerica.append("Yes")
        elif "Europe" in continente or "Europe," in continente or "Antarctica" in continente or "Antarctica," in continente or "Africa" in continente or "Africa," in continente or "SouthAmerica" in continente or "SouthAmerica," in continente or "Oceania" in continente or "Oceania," in continente or "Asia" in continente or "Asia," in continente:
            lista_NorthAmerica.append("No")                          
        else:
            lista_NorthAmerica.append(np.nan)
    else:
        lista_NorthAmerica.append(np.nan)


combinados = zip(lista_global,lista_global2)
for valor, col in tqdm(combinados):
        try:
            if "MATING BEHAVIOR" in col:
                lista_tipo_relación.append(valor[0].replace("\n","").replace(" ",""))
            else:
                lista_tipo_relación.append(np.nan)
        except:
            lista_tipo_relación.append(np.nan)
        try:
            if "REPRODUCTION SEASON" in col and "MATING BEHAVIOR" in col:
                v = valor[1].replace("\n","").split(" ")
                lista_epoca_reproducción.append(v[0])
            elif "REPRODUCTION SEASON" in col:
                v = valor[0].replace("\n","").split(" ")
                lista_epoca_reproducción.append(v[0])
            else:
                lista_epoca_reproducción.append(np.nan)
        except:
            lista_epoca_reproducción.append(np.nan)
        try:
            if "REPRODUCTION SEASON" in col and "MATING BEHAVIOR" in col and "PREGNANCY DURATION" in col:
                lista_periodo_embarazo.append(valor[2].replace("\n","").replace(",",".").split(" "))
            elif ("REPRODUCTION SEASON" in col and "PREGNANCY DURATION" in col) or ("MATING BEHAVIOR" in col and "PREGNANCY DURATION" in col):
                lista_periodo_embarazo.append(valor[1].replace("\n","").replace(",",".").split(" "))
            elif "PREGNANCY DURATION" in col:
                lista_periodo_embarazo.append(valor[0].replace("\n","").replace(",",".").split(" "))
            else:
                lista_periodo_embarazo.append("np.nan")
        except:
            lista_periodo_embarazo.append("np.nan")
        try:
            if "REPRODUCTION SEASON" in col and "MATING BEHAVIOR" in col and "PREGNANCY DURATION" in col and "BABY CARRYING" in col:
                elemento = valor[3].replace("\n","").replace("'","").split (" ")
                lista_numero_crias.append(elemento[0].split("-"))
                for indice in lista_numero_crias:
                    for numero in indice:
                        num = int(numero)
                        lista_numero_crias_final.append(num)
                    lista_final.append(lista_numero_crias_final)
                    lista_numero_crias_final = []
                    for indice in lista_final:
                        suma_total = sum(indice)
                        cantidad_elementos = len(indice)
                        promedio = suma_total / cantidad_elementos
                lista_numero_crias_media.append(promedio)
            elif "BABY CARRYING" in col[2]:
                elemento = valor[2].replace("\n","").replace("'","").split (" ")
                lista_numero_crias.append(elemento[0].split("-"))
                for indice in lista_numero_crias:
                    for numero in indice:
                        num = int(numero)
                        lista_numero_crias_final.append(num)
                    lista_final.append(lista_numero_crias_final)
                    lista_numero_crias_final = []
                    for indice in lista_final:
                        suma_total = sum(indice)
                        cantidad_elementos = len(indice)
                        promedio = suma_total / cantidad_elementos
                lista_numero_crias_media.append(promedio)
            elif "BABY CARRYING" in col[1]:
                elemento = valor[1].replace("\n","").replace("'","").split (" ")
                lista_numero_crias.append(elemento[0].split("-"))
                for indice in lista_numero_crias:
                    for numero in indice:
                        num = int(numero)
                        lista_numero_crias_final.append(num)
                    lista_final.append(lista_numero_crias_final)
                    lista_numero_crias_final = []
                    for indice in lista_final:
                        suma_total = sum(indice)
                        cantidad_elementos = len(indice)
                        promedio = suma_total / cantidad_elementos
                lista_numero_crias_media.append(promedio)
            elif "BABY CARRYING" in col[0]:
                elemento = valor[0].replace("\n","").replace("'","").split (" ")
                lista_numero_crias.append(elemento[0].split("-"))
                for indice in lista_numero_crias:
                    for numero in indice:
                        num = int(numero)
                        lista_numero_crias_final.append(num)
                    lista_final.append(lista_numero_crias_final)
                    lista_numero_crias_final = []
                    for indice in lista_final:
                        suma_total = sum(indice)
                        cantidad_elementos = len(indice)
                        promedio = suma_total / cantidad_elementos
                lista_numero_crias_media.append(promedio)
            else:
                lista_numero_crias_meedia.append(np.nan)
        except:
            lista_numero_crias_media.append(np.nan)
        try:
            if "INDEPENDENT AGE" in col[4]:
                lista_independientes.append(valor[4].replace("\n","").replace(",",".").split(" "))
            elif "INDEPENDENT AGE" in col[3]:
                lista_independientes.append(valor[3].replace("\n","").replace(",",".").split(" "))
            elif "INDEPENDENT AGE" in col[2]:
                lista_independientes.append(valor[2].replace("\n","").replace(",",".").split(" "))
            elif "INDEPENDENT AGE" in col[1]:
                lista_independientes.append(valor[1].replace("\n","").replace(",",".").split(" "))
            elif "INDEPENDENT AGE" in col[0]:
                lista_independientes.append(valor[0].replace("\n","").replace(",",".").split(" "))
            else:
                lista_independientes.append("np.nan")
        except:
            lista_independientes.append("np.nan")
        

for elemento in lista_periodo_embarazo:
    if elemento[1] =="days" or elemento[1] =="day":
        try:
            el = elemento[0].split("-")
            a = ((float(el[1])+float(el[0]))/2)/30
            lista_periodo.append(a)
        except:
            lista_periodo.append(float(elemento[0])/30)
    elif elemento[1] =="week" or elemento[1] =="weeks":
        try:
            el = elemento[0].split("-")
            a = ((float(el[1])+float(el[0]))/2)/4
            lista_periodo.append(a)
        except:
            lista_periodo.append(float(elemento[0])/4)
    elif elemento[1] =="month" or elemento[1] =="months":
        try:
            el = elemento[0].split("-")
            a = ((float(el[1])+float(el[0]))/2)
            lista_periodo.append(a)
        except:
             lista_periodo.append(float(elemento[0]))
    elif elemento[1] =="year" or elemento[1] =="years":
        try:
            el = elemento[0].split("-")
            a = ((float(el[1])+float(el[0]))/2)*12
            lista_periodo.append(a)
        except:
            lista_periodo.append(float(elemento[0])*12)
    else:
        lista_periodo.append(np.nan)

for elemento in lista_independientes:
    if len(elemento) >1:
        if elemento[1] =="days" or elemento[1] =="day":
            try:
                ele = elemento[0].split("-")
                ae = ((float(ele[1])+float(ele[0]))/2)/30
                lista_independientes_final.append(ae)
            except:
                lista_independientes_final.append(float(elemento[0])/30)
        elif elemento[1] =="week" or elemento[1] =="weeks":
            try:
                ele = elemento[0].split("-")
                ae = ((float(ele[1])+float(ele[0]))/2)/4
                lista_independientes_final.append(ae)
            except:
                lista_independientes_final.append(float(elemento[0])/4)
        elif elemento[1] =="month" or elemento[1] =="months":
            try:
                ele = elemento[0].split("-")
                ae = ((float(ele[1])+float(ele[0]))/2)
                lista_independientes_final.append(ae)
            except:
                lista_independientes_final.append(float(elemento[0]))
        elif elemento[1] =="year" or elemento[1] =="years":
            try:
                ele = elemento[0].split("-")
                ae = ((float(ele[1])+float(ele[0]))/2)*12
                lista_independientes_final.append(ae)
            except:
                lista_independientes_final.append(float(elemento[0])*12)
        else:
            lista_independientes_final.append(np.nan)
    else:
        lista_independientes_final.append(np.nan)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#   0%|          | 0/6348 [00:00<?, ?it/s]
# Lion
# Tiger
# Blue Whale
# no tiene titulo
# Killer Whale
# no tiene titulo
# Giant Panda
# Grey Wolf
# Brown Bear
# Koala
# Platypus
# Jaguar
# Cougar
# Polar Bear
# Quokka
# Horse
# Raccoon
# Cheetah
# Coyote
# no tiene titulo
# Moose
# Narwhal
# Leopard
# Common Hippo
# no tiene titulo
# Bobcat
# Wolverine
# Red Panda
# Dingo
# Alpaca
# Domestic Guinea Pig
# Tasmanian Devil
# Capybara
# no tiene titulo
# Domestic Sheep
# Sperm Whale
# American Bison
# Honey Badger
# Bengal Tiger
# Bonobo
# Donkey
# no tiene titulo
# Goat
# no tiene titulo
# Llama
# no tiene titulo
# Snow Leopard
# Wild Boar
# Red Fox
# American Black Bear
# Raccoon Dog
# Groundhog
# Meerkat
# African Wild Dog
# no tiene titulo
# Fisher
# Domesticated Ferret
# Beluga Whale
# no tiene titulo
# Reindeer
# Walrus
# no tiene titulo
# Dugong
# Elk
# Ocelot
# Coypu
# Common Chimpanzee
# Aardvark
# Sugar Glider
# no tiene titulo
# ...

# %%
data = {'NAME': nombre_animal,"KINGDOM":kingdom, "PHYLUM":phylum, "SUBPHYLUM": subphylum, "CLASS":claass, "ORDER": order, "SUBORDER": suborder,
        "FAMILY": family, "GENUS": genus, "POPU-SIZE": popu_size, "LIFESPAN(Y)": life_span, "TOPSPEED(KM/H)":top_speed, "WEIGHT(KG)": weight_list, "LENGTH(CM)":lenght_list,
        "HEIGHT": height_list, "ACTIVITY-PERIOD":horario, "REPRODUCTION":reproduccion, "LIFESTYLE": estilo_de_vida, "SOCIAL":sociabilidad, "DOMESTICATED": domestiscado, 
        "TYPE": tipo, "DIET": dieta,"POISONOUS":veneno, 'MATING-BEHAVIOR': lista_tipo_relación,"REPRODUCTION-SEASON": lista_epoca_reproducción, "PREGNANCY-DURATION": lista_periodo, 
        "BABY-CARRYING": lista_numero_crias_media, "INDEPENDENT-AGE": lista_independientes_final, "EUROPE": lista_Europa, "ASIA": lista_Asia, "OCEANIA": lista_Oceania,
        "SOUTH-AMERICA": lista_SouthAmerica, "NORTH-AMERICA": lista_NorthAmerica, "ANTARCTICA": lista_Antarctica, "AFRICA": lista_Africa,
        "FOREST": lista_forest, "DUNES": lista_dunes, "RIVERS": lista_rivers, "MARINE": lista_marine, "REEF": lista_reef,
        "SEMI-DESERT": lista_semi_desert, "STEPPE": lista_steppe, "FRESHWATTER":lista_freshwater, "ABYSSAL-ZONE":lista_abyssal_zone, "ICECAP":lista_icecap,
        "RAINFOREST": lista_rainforest, "INTERTIDAL-ZONE": lista_intertidal_zone, "URBAN": lista_urban, "BENTHIC": lista_benthic, "ROCKY-AREAS": lista_rocky_areas,
        "WETLANDS": lista_wetlands, "MARSH": lista_marsh, "LAKES": lista_lakes, "COASTAL": lista_coastal, "CHAPARRAL": lista_chaparral, "SHRUBLAND": lista_shrubland,
        "ANTROPHOGENIC": lista_antrophogenic, "ESTUARIES": lista_estuaries, "OCEANIC-PELAGIC-ZONE": lista_oceanic_pelagic_zone, "CAVES": lista_caves,
        "GRASSLAND": lista_grassland, "SAVANNA": lista_savanna, "MOUNTAINS": lista_mountains, "RIPARIAN": lista_riparian, "NERITIC-ZONE": lista_neritic_zone,
        "AGRICULTURAL": lista_agricultural, "ARID": lista_arid, "COLD": lista_cold, "TEMPERATE": lista_temperate, "POLAR": lista_polar, "TROPICAL": lista_tropical,
        "POPU-STATUS": lista_estado_pob, "POPU-TREND": lista_tendencia_pob}
df = pd.DataFrame(data)

# %%
df.to_csv("df_animales.csv", index = False)

# %% [markdown]
# · UNA VEZ CREADO EL DATAFRAME A PARTIR DEL WEBSCRAPPING UTILIZAMOS UNA API PARA AÑADIR MÁS INFORMACIÓN AL DATAFRAME INICIAL!

# %%
datos = pd.read_csv("df_animales.csv")
df = pd.DataFrame(datos)

# %%
columns_to_process = ['POPU-SIZE', 'LIFESPAN(Y)', 'TOPSPEED(KM/H)', 'WEIGHT(KG)',"LENGTH(CM)","HEIGHT"]
df[columns_to_process] = df[columns_to_process].fillna("NO")
df[columns_to_process] = df[columns_to_process].replace("nan","NO")
df[columns_to_process] = df[columns_to_process].replace("NO", 0)
df[columns_to_process] = df[columns_to_process].astype(float)

# %%
dff = df[df["LIFESPAN(Y)"] == 0]
nombres = dff["NAME"].tolist()

# %%
data2 = []
nombres2 = []

for indice, animal in tqdm(enumerate(nombres)):
    print(animal)
    api_url = 'https://api.api-ninjas.com/v1/animals?name={}'.format(animal)
    response = requests.get(api_url, headers={'X-Api-Key': 'Tt1HpjQhnX0rsrCSwLvm6g==eiY6Hz8jBkNDIgwa'})
    try:
        if response.status_code == requests.codes.ok:
            data = json.loads(response.text)
            data2.append(data[0])
            data = 0
            nombres2.append(animal)
        else:
            print("Error:", response.status_code, response.text)
    except:
        data2.append(np.nan)
# Out:
# 0it [00:00, ?it/s]
# Horse
# Goat
# Serval
# Kodiak bear
# Kodiak bear
# Colossal squid
# Geoduck
# Cane toad
# Domestic pigeon
# Common garter snake
# Northern white rhinoceros
# Red wolf
# Zebu
# Loggerhead sea turtle
# Olm
# Giant Pacific octopus
# Common octopus
# California grizzly bear
# Fancy rat
# Hairy frog
# American bullfrog
# Mountain gorilla
# Western lowland gorilla
# Kermode bear
# Colorado River toad
# Northwestern Wolf
# Vampire squid
# Tiger salamander
# Brahminy Blind Snake
# Domestic duck
# Domestic turkey
# Domestic canary
# Eurasian wolf
# Humboldt squid
# Hellbender
# Eurasian brown bear
# Olive ridley sea turtle
# American green tree frog
# Golden poison frog
# Tarpan
# Fire salamander
# Banded Krait
# Zebra mussel
# Pyrenean ibex
# Common toad
# Hokkaido wolf
# Armbruster's wolf
# Cross River gorilla
# Burchell's zebra
# Blesbok
# Himalayan black bear
# Sunda Pangolin
# Chinese Mountain Cat
# Saimaa ringed seal
# Marco Polo sheep
# Eastern elk
# ...

# %%
lifespan22 = []
for n in tqdm(range(len(data2))):
    try:
        lifespan2 = data2[n]["characteristics"]["lifespan"]
        try:
            lifespan2 = (float(lifespan2.split("-")[0]))
            if len (lifespan2) == 1:
                lifespan22.append(lifespan2)
            else:
                lifespan22.append(float(lifespan2.split(" ")[0]))
        except:
            lifespan22.append(lifespan2)
    except:
        pass
# Out:
#   0%|          | 0/5286 [00:00<?, ?it/s]

# %%
nombres2.remove("Colossal squid")
nombres2.remove("Fire salamander")
nombres2.remove("Hellbender")
lifespan22.remove("Hellbender")
for i in range(len(lifespan22)):
    lifespan22[i] = str(lifespan22[i]).replace("100 years", "100")
    lifespan22[i] = lifespan22[i].replace("8 years of adult life, much longer total life span", "8")
    lifespan22[i] = lifespan22[i].replace("A year", "1")
    lifespan22[i] = lifespan22[i].replace("2 to 5 years", "5")
    lifespan22[i] = lifespan22[i].replace("one year", "1")
    lifespan22[i] = lifespan22[i].replace("Six years or less", "6")

# %%
data3 = {"NAME":nombres2, "LIFESPAN(Y)":lifespan22}
df3 = pd.DataFrame(data3)
df = df.merge(df3, on='NAME', how='left')
df['LIFESPAN(Y)_x'] = df['LIFESPAN(Y)_x'].replace(0, np.nan)
df['LIFESPAN(Y)_x'].fillna(df['LIFESPAN(Y)_y'], inplace=True)
df.drop(['LIFESPAN(Y)_y'], axis=1, inplace=True)
df.rename(columns={'LIFESPAN(Y)_x': 'LIFESPAN(Y)'}, inplace=True)

# %% [markdown]
# · YA CON LOS DATOS DE LA API AÑADIDOS AL DATAFRAME INICIAL, PROCEDEMOS A LA TRANSFORMACIÓN Y LIMPIEZA DEL DF!

# %% [markdown]
# · Primero filtramos los animales que tienen 60 columnas o más ya que son con los que trabajaremos.

# %%
filtered_df = df.dropna(thresh=60, )
filtered_df = filtered_df.reset_index(drop=True)

# %% [markdown]
# · Eliminamos la columna DIET porque presentaba errores y no iba a ser útil.

# %%
filtered_df = filtered_df.drop("DIET", axis=1)

# %% [markdown]
# · Eliminamos algunos animales que se han filatrado mal en la web y no son mamiferos.

# %%
filtered_df = filtered_df[filtered_df["CLASS"] == "Mammalia"]

filtered_df.reset_index(drop = True, inplace = True)

# %% [markdown]
# · La columna POPU-TREND presenta algunos valores que pertenecen a la columna POPU-STATUS, por ello, filtramos esos valores y los copiamos en su columna correspondiente.
#   Posteriormente limpiamos la columna POPU-TREND cambiando estos valores por np.nan, que es el valor que realmente debería haber mostrado.

# %%
valores_excluidos = ["Decreasing", "Increasing", "Stable", "Unknown", "patata"]

# Crear una máscara booleana para los valores que no están en la lista de valores excluidos
mascara = ~filtered_df["POPU-TREND"].isin(valores_excluidos)

# Aplicar la máscara al DataFrame para obtener las filas con valores diferentes a los excluidos
resultado = filtered_df[mascara]

copia_resultado = resultado.copy()

# Intercambiar las columnas en la copia
copia_resultado['POPU-STATUS'], copia_resultado['POPU-TREND'] = copia_resultado['POPU-TREND'], copia_resultado['POPU-STATUS']

filtered_df = copia_resultado.combine_first(filtered_df)
filtered_df['POPU-TREND'] = filtered_df['POPU-TREND'].replace('Unknown', np.nan)

filtered_df["POPU-TREND"] = np.where(~filtered_df["POPU-TREND"].isin(["Decreasing", "Increasing", "Stable"]), np.nan, filtered_df["POPU-TREND"])

# %% [markdown]
# · Limpiamos la columna MATING-BEHAVIOR eliminando los valores dobles.

# %%
filtered_df['MATING-BEHAVIOR'] = filtered_df['MATING-BEHAVIOR'].str.split(',').str[0]

# %% [markdown]
# · Añadimos las unidades de medida en el título a las columnas que les falta.

# %%
filtered_df = filtered_df.rename(columns={'PREGNANCY-DURATION': 'PREGNANCY-DURATION(M)',"HEIGHT":"HEIGHT(CM)","BABY-CARRYING":"BABY-CARRYING(M)","INDEPENDENT-AGE":"INDEPENDENT-AGE(M)"})

# %% [markdown]
# · Redondeamos a un decimal las columnas que tienen muchos decimales.

# %%
filtered_df['PREGNANCY-DURATION(M)'] = filtered_df['PREGNANCY-DURATION(M)'].round(1)

# %% [markdown]
# · Finalmente, optimizamos el espacio que ocupa en la memoria el df, cambiando el tipo de datos que contiene.

# %%
filtered_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1430 entries, 0 to 1429
# Data columns (total 72 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NAME                   1430 non-null   category
#  1   KINGDOM                1430 non-null   category
#  2   PHYLUM                 1430 non-null   category
#  3   SUBPHYLUM              1430 non-null   category
#  4   CLASS                  1430 non-null   category
#  5   ORDER                  1430 non-null   category
#  6   SUBORDER               1430 non-null   category
#  7   FAMILY                 1430 non-null   category
#  8   GENUS                  1430 non-null   object
#  9   POPU-SIZE              1430 non-null   float32
#  10  LIFESPAN(Y)            1430 non-null   float64
#  11  TOPSPEED(KM/H)         1430 non-null   float32
#  12  WEIGHT(KG)             1430 non-null   float32
#  13  LENGTH(CM)             1430 non-null   float32
# ...

# %%
columnas_object = filtered_df.select_dtypes(include=['object']).columns
filtered_df[columnas_object] = filtered_df[columnas_object].astype('category')

# %%
columnas_float = filtered_df.select_dtypes(include=['float64']).columns
filtered_df[columnas_float] = filtered_df[columnas_float].astype('float32')

# %%
filtered_df["LIFESPAN(Y)"] = filtered_df["LIFESPAN(Y)"].astype('float64')
filtered_df["GENUS"] = filtered_df["GENUS"].astype('object')
filtered_df["ACTIVITY-PERIOD"] = filtered_df["ACTIVITY-PERIOD"].astype('object')
filtered_df["REPRODUCTION"] = filtered_df["REPRODUCTION"].astype('object')

# %% [markdown]
# · YA CON NUESTRO DATAFRAME LIMPIO, LO SUBIMOS A AIRTABLE!

# %%
#CORRECCION DATOS, AIRTABLE
filtered_df_air_string = ['NAME', 'KINGDOM', 'PHYLUM', 'SUBPHYLUM', 'CLASS', 'ORDER', 'SUBORDER',
       'FAMILY', 'GENUS','ACTIVITY-PERIOD', 'REPRODUCTION',
       'LIFESTYLE', 'SOCIAL', 'DOMESTICATED', 'TYPE', 'MATING-BEHAVIOR',
       'REPRODUCTION-SEASON','EUROPE', 'ASIA', 'OCEANIA', 'SOUTH-AMERICA',
       'NORTH-AMERICA', 'ANTARCTICA', 'AFRICA', 'FOREST', 'DUNES', 'RIVERS',
       'MARINE', 'REEF', 'SEMI-DESERT', 'STEPPE', 'FRESHWATTER',
       'ABYSSAL-ZONE', 'ICECAP', 'RAINFOREST', 'INTERTIDAL-ZONE', 'URBAN',
       'BENTHIC', 'ROCKY-AREAS', 'WETLANDS', 'MARSH', 'LAKES', 'COASTAL',
       'CHAPARRAL', 'SHRUBLAND', 'ANTROPHOGENIC', 'ESTUARIES',
       'OCEANIC-PELAGIC-ZONE', 'CAVES', 'GRASSLAND', 'SAVANNA', 'MOUNTAINS',
       'RIPARIAN', 'NERITIC-ZONE', 'AGRICULTURAL', 'ARID', 'COLD', 'TEMPERATE',
       'POLAR', 'TROPICAL', 'POPU-STATUS', 'POPU-TREND',"POISONOUS"]

filtered_df_air_num = ['POPU-SIZE', 'LIFESPAN(Y)', 'TOPSPEED(KM/H)',
       'WEIGHT(KG)', 'LENGTH(CM)', 'HEIGHT(CM)','BABY-CARRYING(M)',
       'INDEPENDENT-AGE(M)','PREGNANCY-DURATION(M)']
filtered_df[filtered_df_air_string] = filtered_df[filtered_df_air_string].replace(np.nan,"patata")
filtered_df[filtered_df_air_num] = filtered_df[filtered_df_air_num].replace(np.nan,0)

# %%
#SUBIR ARCHIVOS A AIRTABLE
url = f"https://api.airtable.com/v0/{BASE_ID}/{TABLE_NAME}"
headers = {
    "Authorization": "Bearer patrGrprzpqjMJ6ck.2039bfe0dca5e50e2ee97c4dbd381d054983006a8e31b062629cdbdcccdf8e93",
    "Content-Type": "application/json"
}

# SUBIR DATOS DE 10 EN 10
batch_size = 10
num_records = filtered_df.shape[0]
batches = [filtered_df[i:i+batch_size] for i in range(0, num_records, batch_size)]

for batch in tqdm(batches):
    datos_subir = {"records": [{"fields": batch.iloc[i, :].to_dict()} for i in range(batch.shape[0])]}
    data = json.dumps(datos_subir)

    # SE PITE EL FOR PARA CADA 10 VALORES
    response = requests.post(url, headers=headers, data=data)

    # COMPROBACION
    if response.status_code == 200:
        print("Solicitud exitosa")
        print(response.json())
    else:
        print("Error en la solicitud:")
        print(response.status_code, response.text)
# Out:
#   0%|          | 0/143 [00:00<?, ?it/s]
# Solicitud exitosa
# ...

# %%
# DESCARGAR ARCHIVOS

params = {"fields"                : None, 
          "maxRecords"            : None, 
          "pageSize"              : None,
          "returnFieldsByFieldId" : False}

response = requests.get(url = url, headers = headers, params = params)
print(f"response: {response.status_code}")

print(f"endpoint: {response.url}")

print("-"*120)

pprint(response.json(), sort_dicts = True)

print("-"*120)

records_id = [x["id"] for x in response.json()["records"]]
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb?returnFieldsByFieldId=False
# ------------------------------------------------------------------------------------------------------------------------
# {'offset': 'itrieIAmkin5rfdvA/rec4BEcZUUhlh81b6',
#  'records': [{'createdTime': '2023-11-04T18:49:06.000Z',
#               'fields': {'ABYSSAL-ZONE': 'No',
#                          'ACTIVITY-PERIOD': "['Nocturnal', 'Diurnal']",
#                          'AFRICA': 'Yes',
#                          'AGRICULTURAL': 'No',
#                          'ANTARCTICA': 'No',
#                          'ANTROPHOGENIC': 'No',
#                          'ARID': 'No',
#                          'ASIA': 'No',
#                          'BABY-CARRYING(M)': 1,
#                          'BENTHIC': 'No',
#                          'CAVES': 'No',
#                          'CHAPARRAL': 'No',
#                          'CLASS': 'Mammalia',
# ...

# %%
# %%time

params = {}

url = f"https://api.airtable.com/v0/{BASE_ID}/{TABLE_NAME}"

datos = list()

while params.get("offset") != None or len(datos) == 0:
    
    response = requests.get(url = url, headers = headers, params = params)
    
    print(f"response: {response.status_code}")
    print(f"endpoint: {response.url}")
    
    data = response.json()
    
    offset = data.get("offset")
    
    params["offset"] = offset
    
    datos.extend(data["records"])
    
print(len(datos))
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb?offset=itreVX1NESMeLnNqn%2Frec4BEcZUUhlh81b6
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb?offset=itreVX1NESMeLnNqn%2Frec8fNRTT3N5siy7Q
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb?offset=itreVX1NESMeLnNqn%2FrecCLYbxvcEEStrT4
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb?offset=itreVX1NESMeLnNqn%2FrecHE0zVAtonwmX1K
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb?offset=itreVX1NESMeLnNqn%2FrecLaF4KS9G3l1j5Q
# response: 200
# endpoint: https://api.airtable.com/v0/appnoz8hECBYemFZr/tblzGPftGkpBXpaWb?offset=itreVX1NESMeLnNqn%2FrecPcW0DSASj2tk1O
# response: 200
# ...

# %%
df2 = pd.json_normalize(datos)
df2.columns = [c.split('.')[1]  if 'fields' in c else c for c in df2.columns]

# %%
df2[filtered_df_air_string] = df2[filtered_df_air_string].replace("patata",np.nan)
df2[filtered_df_air_num] = df2[filtered_df_air_num].replace(0, np.nan)

# %%
df2
# Out:
#                      id               createdTime  \
# 0     rec03gojdZiwGxP7i  2023-11-04T18:49:06.000Z
# 1     rec05JJw1E0GPkR8R  2023-11-04T18:51:04.000Z
# 2     rec08jhhQ08zxOZYI  2023-11-04T18:49:52.000Z
# 3     rec09oQ6YDz9UE2r1  2023-11-04T18:49:35.000Z
# 4     rec0AsSJ30KZN5qE6  2023-11-04T18:51:07.000Z
# ...                 ...                       ...
# 1425  reczuzLQXZA9QoFtQ  2023-11-04T18:49:28.000Z
# 1426  reczwetXMYUsHfYln  2023-11-04T18:50:41.000Z
# 1427  reczxrdKokSsGFeGz  2023-11-04T18:49:58.000Z
# 1428  reczyXhkTxpIlQSB3  2023-11-04T18:50:32.000Z
# 1429  reczzzMZ9KMUXjTHH  2023-11-04T18:49:03.000Z
#
#                              NAME    PHYLUM   SUBPHYLUM     CLASS  \
# 0                 African Buffalo  Chordata  Vertebrata  Mammalia
# 1             Julia Creek Dunnart  Chordata  Vertebrata  Mammalia
# 2                Kordofan Giraffe  Chordata  Vertebrata  Mammalia
# 3                   Golden Monkey  Chordata  Vertebrata  Mammalia
# ...

# %%
df2.to_csv("df_Proyecto1_Animalia.csv", index = False)
